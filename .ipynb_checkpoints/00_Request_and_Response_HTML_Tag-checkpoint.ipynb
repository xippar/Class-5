# %%
# !pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\acer\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\acer\anaconda3\lib\site-packages (from bs4) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\acer\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)

# %%
import requests
import bs4

# %%
name_list = []
link_list = []

for page in range(1,6):
    part_url = 'https://www.checkraka.com/house/?quicksearch_order=update%2CDESC&page='
    url = part_url + str(page)
    data = requests.get(url)
    soup = bs4.BeautifulSoup(data.text)
    residence_list = soup.find_all('div',{'class':'content c44'})

    for residence in residence_list:
        first_ul = residence.find_all('ul',recursive=False)[0]
        second_li = first_ul.find_all('li',recursive=False)[1]
        data = second_li.find('a')
        link_list.append('https://www.checkraka.com' + data.get('href'))
        name_list.append(data.text)
    print('Completed page number',page)
# Out:
# Completed page number 1
# Completed page number 2
# Completed page number 3
# Completed page number 4
# Completed page number 5

# %%
import pandas as pd

# %%
data_df = pd.DataFrame([name_list,link_list]).transpose()
data_df.columns = ['residence','url']
data_df = data_df.set_index('residence')
data_df
# Out:
#                                                                                                   url
# residence
# สิริ เพลส แอร์พอร์ต ภูเก็ต (Siri Place Airport)     https://www.checkraka.com/house/sansiri/siri-p...
# คณาสิริ ศาลายา - ปิ่นเกล้า (Kanasiri Salaya - P...  https://www.checkraka.com/house/sansiri/kanasi...
# คณาสิริ พระราม 2 - วงแหวน (Kanasiri Rama 2 - Wo...  https://www.checkraka.com/house/sansiri/kanasi...
# บุราสิริ รังสิต (Burasiri Rangsit)                  https://www.checkraka.com/house/sansiri/burasi...
# สราญสิริ โคราช (Saransiri Korat)                    https://www.checkraka.com/house/sansiri/sarans...
# เอชเคป ซีรีน บางนา - วงแหวน (H-CAPE Serene Bang...  https://www.checkraka.com/house/เอชเคป-ซีรีน-บ...
# บุราสิริ สันผีเสื้อ เชียงใหม่ (Burasiri Sanphis...  https://www.checkraka.com/house/sansiri/burasi...
# ทาวน์ อเวนิว สองแคว-พิษณุโลก (Town Avenue Songk...  https://www.checkraka.com/house/sansiri/town-a...
# คณาสิริ ชัยพฤกษ์ - วงแหวน (Kanasiri Chaiyapruek...  https://www.checkraka.com/house/sansiri/kanasi...
# ฮาบิเทีย ไพร์ม ราชพฤกษ์ (Habitia Prime Ratchapr...  https://www.checkraka.com/house/sansiri/habiti...
# 1517 นิมมาน (1517 Nimman)                            https://www.checkraka.com/house/sansiri/1455228/
# วิลลาจจิโอ สุขสวัสดิ์-ประชาอุทิศ (Villaggio Suk...  https://www.checkraka.com/house/land-and-house...
# พาทิโอ กัลปพฤกษ์ - สาทร (Patio Kalapapruek - Sa...    https://www.checkraka.com/house/pruksa/1455220/
# ลลิล ทาวน์ แลนซีโอ คริป บางนา - สุวรรณภูมิ (Lal...  https://www.checkraka.com/house/lalin/lanceo-c...
# พาทิโอ งามวงศ์วาน - ประชาชื่น (Patio Ngamwongwa...  https://www.checkraka.com/house/pruksa/patio/1...
# พาทิโอ รัชโยธิน (Patio Ratchayothin)                https://www.checkraka.com/house/pruksa/patio/1...
# ศุภาลัย ไพร์ด ศรีราชา (Supalai pride Sriracha)      https://www.checkraka.com/house/supalai/supala...
# ศุภาลัย ปาล์มสปริงส์ ระยอง (Supalai Palm Spring...   https://www.checkraka.com/house/supalai/1455214/
# ศุภาลัย พรีโม่ หนองบัวศาลา นครราชสีมา (Supalai ...  https://www.checkraka.com/house/supalai/supala...
# ศุภาลัย รอยัล ริเวอร์ 2 ขอนแก่น (Supalai Royal ...  https://www.checkraka.com/house/supalai/supala...
# บ้านฟ้าปิยรมย์ นีโอลา ลำลูกกา คลอง 6 (Baan Fah ...  https://www.checkraka.com/house/ncgroup/baan-f...
# บ้านพันนา เอกมัย-รามอินทรา 3 (Baan Panna Ekkama...  https://www.checkraka.com/house/บ้านพันนา-เอกม...
